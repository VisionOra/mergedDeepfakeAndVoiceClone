# %% [markdown]
# # Collab preliminaries

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# # Get the code and models

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.

# %%
# !ls
# Out:
# gdrive	sample_data  Wav2Lip

# %%
# !cp -ri "/content/gdrive/My Drive/Wav2lip/wav2lip.pth" /content/Wav2Lip/checkpoints/

# %% [markdown]
# # Get the pre-requisites

# %%
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# Uninstalling tensorflow-2.3.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.3.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
# y
# y
#   Successfully uninstalled tensorflow-2.3.0
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# !cd Wav2Lip && pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 1.6MB 10.7MB/s
# ...
#      |████████████████████████████████| 20.4MB 1.3MB/s
# ...
#      |████████████████████████████████| 34.2MB 157kB/s
# ...
#      |████████████████████████████████| 26.6MB 126kB/s
# ...
#      |████████████████████████████████| 58.4MB 50kB/s
# ...
#      |████████████████████████████████| 676.9MB 14kB/s
# ...
#      |████████████████████████████████| 2.6MB 49.8MB/s
# ...
#      |████████████████████████████████| 61kB 7.5MB/s
# ...
#      |████████████████████████████████| 573kB 61.0MB/s
# ...
#      |████████████████████████████████| 3.3MB 47.0MB/s
# ...
#   Created wheel for librosa: filename=librosa-0.7.0-cp36-none-any.whl size=1598345 sha256=5477864fb5774b08e121b8a79ad4c597c2bed0c026b917686282982d13e421c7
#   Stored in directory: /root/.cache/pip/wheels/49/1d/38/c8ad12fcad67569d8e730c3275be5e581bd589558484a0f881
# Successfully built librosa
# ERROR: xarray 0.15.1 has requirement setuptools>=41.2, but you'll have setuptools 39.1.0 which is incompatible.
# ...

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2020-08-29 04:37:30--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 95.179.192.69
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|95.179.192.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M   498KB/s    in 2m 55s
#
# 2020-08-29 04:40:28 (500 KB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %% [markdown]
# # Now lets try!

# %%
# !cp "/content/gdrive/My Drive/Wav2Lip/input_vid.mp4" "/content/gdrive/My Drive/Wav2Lip/input_audio.wav" sample_data/
# !ls sample_data/
# Out:
# anscombe.json		      input_audio.wav  mnist_train_small.csv
# california_housing_test.csv   input_vid.mp4    README.md
# california_housing_train.csv  mnist_test.csv

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "/content/Wav2Lip/mmm1.mp4" --audio "/content/Wav2Lip/shb1.ogg"
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# use the "files" button on the left to download the result in the Wav2Lip/results/ folder.

# %% [markdown]
# ## **Variations to try**

# %% [markdown]
# 1.   Use more padding to include the chin region

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "../sample_data/input_vid.mp4" --audio "../sample_data/input_audio.wav" --pads 0 20 0 0

# %% [markdown]
# 2.   Use resize_factor to reduce the video resolution, as there is a change you might get better results for lower resolution videos. Why? Because the model was trained on low resolution faces.

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "../sample_data/input_vid.mp4" --audio "../sample_data/input_audio.wav" --resize_factor 2
