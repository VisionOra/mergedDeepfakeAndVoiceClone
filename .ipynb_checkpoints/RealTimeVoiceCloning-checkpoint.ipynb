# %% [markdown]
# # Real-Time Voice Cloning
#
# This is a colab demo notebook using the open source project [CorentinJ/Real-Time-Voice-Cloning](https://github.com/CorentinJ/Real-Time-Voice-Cloning)
# to clone a voice.
#
# For other deep-learning Colab notebooks, visit [tugstugi/dl-colab-notebooks](https://github.com/tugstugi/dl-colab-notebooks).
#
#
# Original issue: https://github.com/tugstugi/dl-colab-notebooks/issues/18
#
# ## Setup CorentinJ/Real-Time-Voice-Cloning

# %%
# !pip install -r requirements_deepFake.txt
# !pip install multiprocess
# !pip install multiprocess
# !pip install librosa
# !pip install llvmlite
# !pip install numba
# !pip install llvmlite 0.33
# !pip uninstall -y numba
# !pip uninstall -y llvmlite

# !pip --use-feature=2020-resolver install numba==0.43.0
# !pip --use-feature=2020-resolver install llvmlite==0.31.0
# !pip install llvm
# !pip install fastparquet
# !pip install --upgrade pip
# !python --version
# !sudo apt install python3-llvmlite
# Out:
# Requirement already satisfied: absl-py==0.8.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 1)) (0.8.1)
# Requirement already satisfied: annoy==1.16.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 2)) (1.16.2)
# Collecting appdirs==1.4.4
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Requirement already satisfied: args==0.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 4)) (0.1.0)
# Requirement already satisfied: astor==0.8.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 5)) (0.8.0)
# Requirement already satisfied: atari-py==0.2.6 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 6)) (0.2.6)
# Requirement already satisfied: attrs==19.3.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 7)) (19.3.0)
# Collecting audioread==2.1.8
#   Downloading https://files.pythonhosted.org/packages/2e/0b/940ea7861e0e9049f09dcfd72a90c9ae55f697c17c299a323f0148f913d2/audioread-2.1.8.tar.gz
# Requirement already satisfied: backcall==0.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 9)) (0.1.0)
# Requirement already satisfied: bleach==3.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 10)) (3.1.0)
# Requirement already satisfied: blis==0.4.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 11)) (0.4.1)
# Requirement already satisfied: box2d-py==2.3.8 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 12)) (2.3.8)
# Requirement already satisfied: cachetools==3.1.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 13)) (3.1.1)
# Requirement already satisfied: catalogue==0.0.8 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 14)) (0.0.8)
# Requirement already satisfied: certifi==2019.11.28 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 15)) (2019.11.28)
# Collecting cffi==1.14.2
#   Downloading https://files.pythonhosted.org/packages/82/7e/9cc46f072c9a414b5a6e08c5c2da5db3bff2601e69c4a6d4f6a34e6f9cfc/cffi-1.14.2-cp36-cp36m-manylinux1_x86_64.whl (400kB)
#      |████████████████████████████████| 409kB 10.1MB/s eta 0:00:01
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 17)) (3.0.4)
# Requirement already satisfied: click==6.7 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 18)) (6.7)
# Requirement already satisfied: clint==0.5.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 19)) (0.5.1)
# Requirement already satisfied: cloudpickle==1.2.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 20)) (1.2.2)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 21)) (0.10.0)
# Requirement already satisfied: cymem==2.0.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 22)) (2.0.3)
# Requirement already satisfied: Cython==0.29.14 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 23)) (0.29.14)
# Requirement already satisfied: cytoolz==0.10.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 24)) (0.10.1)
# Requirement already satisfied: decorator==4.4.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 25)) (4.4.1)
# Requirement already satisfied: defusedxml==0.6.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 26)) (0.6.0)
# Collecting dill==0.3.2
#   Downloading https://files.pythonhosted.org/packages/e2/96/518a8ea959a734b70d2e95fef98bcbfdc7adad1c1e5f5dd9148c835205a5/dill-0.3.2.zip (177kB)
#      |████████████████████████████████| 184kB 16.9MB/s eta 0:00:01
# Requirement already satisfied: dlib==19.18.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 28)) (19.18.0)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 29)) (0.3)
# Requirement already satisfied: Flask==1.1.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 30)) (1.1.1)
# Requirement already satisfied: floyd-cli==0.11.17 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 31)) (0.11.17)
# Requirement already satisfied: funcsigs==1.0.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 32)) (1.0.2)
# Requirement already satisfied: future==0.18.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 33)) (0.18.2)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 34)) (0.2.2)
# Requirement already satisfied: google-pasta==0.1.8 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 35)) (0.1.8)
# Requirement already satisfied: grpcio==1.25.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 36)) (1.25.0)
# Requirement already satisfied: gym==0.15.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 37)) (0.15.4)
# Requirement already satisfied: gym-retro==0.7.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 38)) (0.7.0)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 39)) (2.10.0)
# Requirement already satisfied: idna==2.8 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 40)) (2.8)
# Requirement already satisfied: imageio==2.6.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 41)) (2.6.1)
# Requirement already satisfied: importlib-metadata==1.2.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 42)) (1.2.0)
# Requirement already satisfied: incremental==17.5.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 43)) (17.5.0)
# Collecting inflect==4.1.0
#   Downloading https://files.pythonhosted.org/packages/b3/27/15edd6e1519f4e489ff50def9367a62d138baa9c000a053c67ac38156519/inflect-4.1.0-py3-none-any.whl
# Requirement already satisfied: ipykernel==5.1.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 45)) (5.1.3)
# Requirement already satisfied: ipython==7.10.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 46)) (7.10.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 47)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 48)) (7.5.1)
# Requirement already satisfied: itsdangerous==1.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 49)) (1.1.0)
# Requirement already satisfied: jedi==0.15.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 50)) (0.15.1)
# Requirement already satisfied: jellyfish==0.7.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 51)) (0.7.2)
# Requirement already satisfied: Jinja2==2.10.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 52)) (2.10.3)
# Requirement already satisfied: joblib==0.14.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 53)) (0.14.0)
# Requirement already satisfied: json5==0.8.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 54)) (0.8.5)
# Requirement already satisfied: jsonschema==3.2.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 55)) (3.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 56)) (1.0.0)
# Requirement already satisfied: jupyter-client==5.3.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 57)) (5.3.4)
# Requirement already satisfied: jupyter-console==6.0.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 58)) (6.0.0)
# Requirement already satisfied: jupyter-core==4.6.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 59)) (4.6.1)
# Requirement already satisfied: jupyterlab==1.2.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 60)) (1.2.3)
# Requirement already satisfied: jupyterlab-server==1.0.6 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 61)) (1.0.6)
# Requirement already satisfied: kaggle==1.5.6 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 62)) (1.5.6)
# Requirement already satisfied: Keras==2.3.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 63)) (2.3.1)
# Requirement already satisfied: Keras-Applications==1.0.8 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 64)) (1.0.8)
# Requirement already satisfied: Keras-Preprocessing==1.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 65)) (1.1.0)
# Requirement already satisfied: kiwisolver==1.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 66)) (1.1.0)
# Collecting librosa==0.8.0
#   Downloading https://files.pythonhosted.org/packages/26/4d/c22d8ca74ca2c13cd4ac430fa353954886104321877b65fa871939e78591/librosa-0.8.0.tar.gz (183kB)
#      |████████████████████████████████| 184kB 17.3MB/s eta 0:00:01
# Collecting llvmlite==0.34.0
#   Downloading https://files.pythonhosted.org/packages/f3/b7/8a91b513f165e0affdeb975c1fef307c39d1051ce71e8aec1da9dcb317ad/llvmlite-0.34.0-cp36-cp36m-manylinux2010_x86_64.whl (24.6MB)
#      |████████████████████████████████| 24.6MB 11.5MB/s eta 0:00:01
# Requirement already satisfied: Markdown==3.1.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 69)) (3.1.1)
# Requirement already satisfied: MarkupSafe==1.1.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 70)) (1.1.1)
# Requirement already satisfied: marshmallow==2.20.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 71)) (2.20.5)
# Requirement already satisfied: matplotlib==3.1.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 72)) (3.1.2)
# Requirement already satisfied: menpo==0.9.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 73)) (0.9.2)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 74)) (0.8.4)
# Requirement already satisfied: mock==3.0.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 75)) (3.0.5)
# Requirement already satisfied: more-itertools==8.0.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 76)) (8.0.0)
# Requirement already satisfied: mpmath==1.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 77)) (1.1.0)
# Collecting multiprocess==0.70.10
#   Downloading https://files.pythonhosted.org/packages/1a/4e/4591c45b85fbcbcc3de9554e20e079e0006c4332e0a780ed0883f2b07965/multiprocess-0.70.10.zip (2.4MB)
#      |████████████████████████████████| 2.4MB 41.8MB/s eta 0:00:01
# Requirement already satisfied: murmurhash==1.0.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 79)) (1.0.2)
# Requirement already satisfied: nbconvert==5.6.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 80)) (5.6.1)
# Requirement already satisfied: nbformat==4.4.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 81)) (4.4.0)
# Requirement already satisfied: networkx==2.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 82)) (2.4)
# Requirement already satisfied: nltk==3.4.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 83)) (3.4.5)
# Requirement already satisfied: notebook==6.0.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 84)) (6.0.3)
# Collecting numba==0.51.2
#   Downloading https://files.pythonhosted.org/packages/48/78/31f620c3469287f4255d9a1054bee713cd3596fda2711c392ce3021b3c98/numba-0.51.2-cp36-cp36m-manylinux2014_x86_64.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 40.2MB/s eta 0:00:01
# Requirement already satisfied: numpy==1.17.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 86)) (1.17.4)
# Requirement already satisfied: opencv-contrib-python==3.4.0.12 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 87)) (3.4.0.12)
# Requirement already satisfied: opencv-python==4.1.2.30 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 88)) (4.1.2.30)
# Requirement already satisfied: opt-einsum==3.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 89)) (3.1.0)
# Collecting packaging==20.4
#   Downloading https://files.pythonhosted.org/packages/46/19/c5ab91b1b05cfe63cccd5cfc971db9214c6dd6ced54e33c30d5af1d2bc43/packaging-20.4-py2.py3-none-any.whl
# Requirement already satisfied: pandas==0.25.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 91)) (0.25.3)
# Requirement already satisfied: pandocfilters==1.4.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 92)) (1.4.2)
# Requirement already satisfied: parso==0.5.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 93)) (0.5.1)
# Requirement already satisfied: path==13.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 94)) (13.1.0)
# Requirement already satisfied: path.py==12.4.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 95)) (12.4.0)
# Requirement already satisfied: pathlib2==2.3.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 96)) (2.3.5)
# Requirement already satisfied: pbr==5.4.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 97)) (5.4.4)
# Requirement already satisfied: pexpect==4.7.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 98)) (4.7.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 99)) (0.7.5)
# Requirement already satisfied: Pillow==6.2.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 100)) (6.2.1)
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 101)) (1.1.3)
# Requirement already satisfied: plotly==4.3.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 102)) (4.3.0)
# Collecting pooch==1.1.1
#   Downloading https://files.pythonhosted.org/packages/1c/c3/0a423ed09fa22e9003b8bf72c2863fde80585badbc1a726176eaff3cd450/pooch-1.1.1-py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 13.1MB/s eta 0:00:01
# Requirement already satisfied: preshed==3.0.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 104)) (3.0.2)
# Requirement already satisfied: prometheus-client==0.7.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 105)) (0.7.1)
# Requirement already satisfied: prompt-toolkit==2.0.10 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 106)) (2.0.10)
# Requirement already satisfied: protobuf==3.11.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 107)) (3.11.1)
# Requirement already satisfied: ptyprocess==0.6.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 108)) (0.6.0)
# Collecting pycparser==2.20
#   Downloading https://files.pythonhosted.org/packages/ae/e7/d9c3a176ca4b02024debf82342dab36efadfc5776f9c8db077e8f6e71821/pycparser-2.20-py2.py3-none-any.whl (112kB)
#      |████████████████████████████████| 112kB 59.1MB/s eta 0:00:01
# Requirement already satisfied: pydot==1.4.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 110)) (1.4.1)
# Requirement already satisfied: pyemd==0.5.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 111)) (0.5.1)
# Requirement already satisfied: pyglet==1.3.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 112)) (1.3.2)
# Requirement already satisfied: Pygments==2.5.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 113)) (2.5.2)
# Requirement already satisfied: pynvrtc==9.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 114)) (9.2)
# Requirement already satisfied: PyOpenGL==3.1.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 115)) (3.1.4)
# Requirement already satisfied: PyOpenGL-accelerate==3.1.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 116)) (3.1.4)
# Requirement already satisfied: pyparsing==2.4.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 117)) (2.4.5)
# Requirement already satisfied: Pyphen==0.9.5 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 118)) (0.9.5)
# Requirement already satisfied: pyrsistent==0.15.6 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 119)) (0.15.6)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 120)) (2.8.1)
# Requirement already satisfied: python-slugify==4.0.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 121)) (4.0.0)
# Requirement already satisfied: pytz==2019.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 122)) (2019.3)
# Requirement already satisfied: PyWavelets==1.1.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 123)) (1.1.1)
# Requirement already satisfied: PyYAML==5.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 124)) (5.2)
# Requirement already satisfied: pyzmq==18.1.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 125)) (18.1.1)
# Requirement already satisfied: qtconsole==4.6.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 126)) (4.6.0)
# Requirement already satisfied: raven==6.10.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 127)) (6.10.0)
# Requirement already satisfied: requests==2.22.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 128)) (2.22.0)
# Requirement already satisfied: requests-toolbelt==0.9.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 129)) (0.9.1)
# Collecting resampy==0.2.2
#   Downloading https://files.pythonhosted.org/packages/79/75/e22272b9c2185fc8f3af6ce37229708b45e8b855fd4bc38b4d6b040fff65/resampy-0.2.2.tar.gz (323kB)
#      |████████████████████████████████| 327kB 48.7MB/s eta 0:00:01
# Requirement already satisfied: retrowrapper==0.3.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 131)) (0.3.0)
# Requirement already satisfied: retrying==1.3.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 132)) (1.3.3)
# Requirement already satisfied: scikit-image==0.16.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 133)) (0.16.2)
# Requirement already satisfied: scikit-learn==0.22 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 134)) (0.22)
# Requirement already satisfied: scikit-umfpack==0.3.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 135)) (0.3.2)
# Requirement already satisfied: scipy==1.3.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 136)) (1.3.3)
# Requirement already satisfied: seaborn==0.9.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 137)) (0.9.0)
# Requirement already satisfied: Send2Trash==1.5.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 138)) (1.5.0)
# Requirement already satisfied: six==1.13.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 139)) (1.13.0)
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 140)) (0.0)
# Collecting SoundFile==0.10.3.post1
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Requirement already satisfied: spacy==2.2.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 142)) (2.2.3)
# Requirement already satisfied: srsly==0.2.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 143)) (0.2.0)
# Requirement already satisfied: sympy==1.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 144)) (1.4)
# Requirement already satisfied: tabulate==0.8.6 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 145)) (0.8.6)
# Requirement already satisfied: tensorboard==1.15.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 146)) (1.15.0)
# Requirement already satisfied: tensorflow==1.15.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 147)) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 148)) (1.15.1)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 149)) (1.1.0)
# Requirement already satisfied: terminado==0.8.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 150)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 151)) (0.4.4)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 152)) (1.3)
# Requirement already satisfied: textacy==0.9.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 153)) (0.9.1)
# Requirement already satisfied: thinc==7.3.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 154)) (7.3.1)
# Requirement already satisfied: toolz==0.10.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 155)) (0.10.0)
# Collecting torch==1.6.0
#   Downloading https://files.pythonhosted.org/packages/38/53/914885a93a44b96c0dd1c36f36ff10afe341f091230aad68f7228d61db1e/torch-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (748.8MB)
#      |████████████████████████████████| 748.8MB 12kB/s s eta 0:00:01   |▎                               | 6.6MB 40.4MB/s eta 0:00:19     |█████████████▊                  | 320.7MB 69.3MB/s eta 0:00:07     |███████████████▌                | 362.6MB 59.1MB/s eta 0:00:07     |█████████████████               | 395.4MB 59.1MB/s eta 0:00:06     |███████████████████████▏        | 540.9MB 68.0MB/s eta 0:00:04     |██████████████████████████▊     | 625.5MB 32.7MB/s eta 0:00:04     |███████████████████████████▎    | 637.9MB 70.8MB/s eta 0:00:02     |████████████████████████████▎   | 660.5MB 70.8MB/s eta 0:00:02     |████████████████████████████▋   | 668.6MB 70.8MB/s eta 0:00:02
# Requirement already satisfied: tornado==6.0.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 157)) (6.0.3)
# Requirement already satisfied: tqdm==4.40.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 158)) (4.40.0)
# Requirement already satisfied: traitlets==4.3.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 159)) (4.3.3)
# Collecting Unidecode==1.1.1
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 100kB/s  eta 0:00:01
# Requirement already satisfied: urllib3==1.24.3 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 161)) (1.24.3)
# Requirement already satisfied: uWSGI==2.0.18 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 162)) (2.0.18)
# Requirement already satisfied: virtualenv==16.7.8 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 163)) (16.7.8)
# Requirement already satisfied: wasabi==0.4.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 164)) (0.4.2)
# Requirement already satisfied: wcwidth==0.1.7 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 165)) (0.1.7)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 166)) (0.5.1)
# Requirement already satisfied: Werkzeug==0.16.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 167)) (0.16.0)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 168)) (3.5.1)
# Requirement already satisfied: wrapt==1.11.2 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 169)) (1.11.2)
# Requirement already satisfied: xgboost==0.90 in /usr/local/lib/python3.6/site-packages/xgboost-0.90-py3.6.egg (from -r requirements_deepFake.txt (line 170)) (0.90)
# Requirement already satisfied: zipp==0.6.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 171)) (0.6.0)
# Requirement already satisfied: zmq==0.0.0 in /usr/local/lib/python3.6/site-packages (from -r requirements_deepFake.txt (line 172)) (0.0.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/site-packages (from ipython==7.10.1->-r requirements_deepFake.txt (line 46)) (42.0.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/site-packages (from tensorboard==1.15.0->-r requirements_deepFake.txt (line 146)) (0.33.6)
# Building wheels for collected packages: audioread, dill, librosa, multiprocess, resampy
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.8-cp36-none-any.whl size=23092 sha256=3a98ece66fab4337c3f054c6ddd8be366f961575cdf77f53d20ad6c20907c62b
#   Stored in directory: /root/.cache/pip/wheels/b9/64/09/0b6417df9d8ba8bc61a7d2553c5cebd714ec169644c88fc012
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.2-cp36-none-any.whl size=78912 sha256=4c8dc9ae0946773b7f43a897583b522419d5727ee0375551656b08d33ee27775
#   Stored in directory: /root/.cache/pip/wheels/27/4b/a2/34ccdcc2f158742cfe9650675560dea85f78c3f4628f7daad0
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-cp36-none-any.whl size=201376 sha256=f3486b95baad52cf1890fd4d7beec5992f62827d301d4d30006bbe28d0dcf5cf
#   Stored in directory: /root/.cache/pip/wheels/ee/10/1e/382bb4369e189938d5c02e06d10c651817da8d485bfd1647c9
#   Building wheel for multiprocess (setup.py) ... done
#   Created wheel for multiprocess: filename=multiprocess-0.70.10-cp36-none-any.whl size=100504 sha256=5bf9df7e943a66c65f9b1d8b729f9b42e24ce410c7dc31612ddedbf23ca6d1b1
#   Stored in directory: /root/.cache/pip/wheels/c0/97/16/5d5fc187439a97f583ff4bdafc1ae4490e1d75dd350f2c0dfa
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-cp36-none-any.whl size=320719 sha256=5a161492a9622f406302cf32ec2feb3c3f6c7b4a0dee10530c7bdad5fb9db825
#   Stored in directory: /root/.cache/pip/wheels/fa/c1/56/e0e12c6f7f3d2cdea9712b35136a2d40a7817c6210ec096485
# Successfully built audioread dill librosa multiprocess resampy
# Installing collected packages: appdirs, audioread, pycparser, cffi, dill, inflect, llvmlite, numba, resampy, SoundFile, packaging, pooch, librosa, multiprocess, torch, Unidecode
# Successfully installed SoundFile-0.10.3.post1 Unidecode-1.1.1 appdirs-1.4.4 audioread-2.1.8 cffi-1.14.2 dill-0.3.2 inflect-4.1.0 librosa-0.8.0 llvmlite-0.34.0 multiprocess-0.70.10 numba-0.51.2 packaging-20.4 pooch-1.1.1 pycparser-2.20 resampy-0.2.2 torch-1.6.0
# WARNING: You are using pip version 19.3.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip freeze > requirements_deepFake.txt

# %%
#@title Setup CorentinJ/Real-Time-Voice-Cloning

#@markdown * clone the project
#@markdown * download pretrained models
#@markdown * initialize the voice cloning models

# %tensorflow_version 1.x
import os
from os.path import exists, join, basename, splitext

# git_repo_url = 'https://github.com/CorentinJ/Real-Time-Voice-Cloning.git'
# project_name = splitext(basename(git_repo_url))[0]
# print(project_name)
# if not exists(project_name):
#     print("Downloading Files")
#     # clone and install
#     !git clone -q --recursive {git_repo_url}
#     # install dependencies
#     !cd {project_name} && pip install -q -r requirements.txt
#     !pip install -q gdown
#     !apt-get install -qq libportaudio2
#     !pip install -q https://github.com/tugstugi/dl-colab-notebooks/archive/colab_utils.zip

#   # download pretrained model
#     !cd {project_name} && gdown https://drive.google.com/uc?id=1n1sPXvT34yXFLT47QZA6FIRGrwMeSsZc && unzip pretrained.zip
BASE_PATH_VOICE_CLONE = "./voice_clone/"
import sys
sys.path.append(BASE_PATH_VOICE_CLONE)
import numpy as np
from pathlib import Path
from scipy.io import wavfile
from synthesizer.inference import Synthesizer
from encoder import inference as encoder
from vocoder import inference as vocoder


SAMPLE_RATE = 22050
embedding = None


# loading Models
encoder.load_model(BASE_PATH_VOICE_CLONE / Path("encoder/saved_models/pretrained.pt"))
synthesizer = Synthesizer(BASE_PATH_VOICE_CLONE / Path("synthesizer/saved_models/logs-pretrained/taco_pretrained"))
vocoder.load_model(BASE_PATH_VOICE_CLONE / Path("vocoder/saved_models/pretrained/pretrained.pt"))
print("All models Load Sucessfully")
# Out:
# Loaded encoder "pretrained.pt" trained to step 1564501
# Found synthesizer "pretrained" trained to step 278000
# Building Wave-RNN
# Trainable Parameters: 4.481M
# Loading model weights at voice_clone/vocoder/saved_models/pretrained/pretrained.pt
# All models Load Sucessfully
# ./voice_clone/encoder/audio.py:13: UserWarning: Unable to import 'webrtcvad'. This package enables noise removal and is recommended.
#   warn("Unable to import 'webrtcvad'. This package enables noise removal and is recommended.")

# %%
import librosa

def _compute_embedding(audio):
    '''
    Description 
        Loading Embedding from the audio file to clone
        
    Input:
        audio: Audio File 
        
    Output
        Embeddings
    
    '''
    global embedding
    embedding = None
    embedding = encoder.embed_utterance(encoder.preprocess_wav(audio, SAMPLE_RATE))

def read_audio_file(path):
    samples, sample_rate = librosa.load(path)
    _compute_embedding(samples)

audio_file_path = "./voices/sundarPichai.wav"
read_audio_file(audio_file_path)
print("Embedding Loads Sucessfully")
# Out:
# Embedding Loads Sucessfully

# %%
def clone_voice(text):
    
    def synthesize(embed, text):
        print("Synthesizing new audio...")
        #with io.capture_output() as captured:
        specs = synthesizer.synthesize_spectrograms([text], [embed])
        generated_wav = vocoder.infer_waveform(specs[0])
        generated_wav = np.pad(generated_wav, (0, synthesizer.sample_rate), mode="constant")
        print(type(generated_wav))
#         display(Audio(generated_wav, rate=synthesizer.sample_rate, autoplay=True))

    if embedding is None:
        print("first record a voice or upload a voice file!")
    else:
        synthesize(embedding, text)
        print("Voice Clonned Sucessfully")
        
text = "I am bhola record I am here to see you in the middle of the earth hello there" #@param {type:"string"}
clone_voice(text)
# Out:
# Synthesizing new audio...
# {| ████████████████ 76000/76800 | Batch Size: 8 | Gen Rate: 2.6kHz | }<class 'numpy.ndarray'>
# Voice Clonned Sucessfully

# %%
import os
import sys
sys.path.append("./Deepfake/Wav2Lip-master/")
checkpoint_path = "./Deepfake/weights/wav2lip_gan.pth"
video_path = "./Deepfake/Wav2Lip-master/samples/WhatsApp Video 2020-08-30 at 3.52.46 PM (1).mp4"
audio_path = "./Deepfake/Wav2Lip-master/samples/sundarPichai.wav"
infrence_path = "./Deepfake/Wav2Lip-master/inference.py"



# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" 
# !cd './Deepfake/Wav2Lip-master/' && python "inference.py"  --checkpoint_path "./weights/wav2lip_gan.pth" --face "./samples/WhatsApp Video 2020-08-30 at 3.52.46 PM (1).mp4" --audio './samples/sundarPichai.wav'
# Out:
# Using cpu for inference.
# Reading video frames...
# Number of frames available for inference: 100
# (80, 24001)
# Length of mel chunks: 4183
#   0%|                                                    | 0/33 [00:00<?, ?it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▍                                      | 1/7 [00:46<04:37, 46.30s/it]
#  29%|████████████▊                                | 2/7 [01:31<03:49, 45.83s/it]
#  43%|███████████████████▎                         | 3/7 [02:15<03:01, 45.50s/it]
#  57%|█████████████████████████▋                   | 4/7 [03:00<02:15, 45.31s/it]
#  71%|████████████████████████████████▏            | 5/7 [03:45<01:30, 45.09s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [04:29<00:44, 44.96s/it]
# 100%|█████████████████████████████████████████████| 7/7 [04:41<00:00, 40.17s/it]
# Load checkpoint from: ./weights/wav2lip_gan.pth
# Model loaded
#   3%|█▏                                       | 1/33 [04:58<2:39:27, 298.98s/it]

# %%
from os import listdir, path
import numpy as np
import scipy, cv2, os, sys, argparse, audio
import json, subprocess, random, string
from tqdm import tqdm
from glob import glob
import torch, face_detection
from models import Wav2Lip

parser = argparse.ArgumentParser(description='Inference code to lip-sync videos in the wild using Wav2Lip models')

parser.add_argument('--checkpoint_path', type=str, 
					help='Name of saved checkpoint to load weights from', required=True)

parser.add_argument('--face', type=str, 
					help='Filepath of video/image that contains faces to use', required=True)
parser.add_argument('--audio', type=str, 
					help='Filepath of video/audio file to use as raw audio source', required=True)
parser.add_argument('--outfile', type=str, help='Video path to save result. See default for an e.g.', 
								default='results/result_voice.mp4')

parser.add_argument('--static', type=bool, 
					help='If True, then use only first video frame for inference', default=False)
parser.add_argument('--fps', type=float, help='Can be specified only if input is a static image (default: 25)', 
					default=25., required=False)

parser.add_argument('--pads', nargs='+', type=int, default=[0, 10, 0, 0], 
					help='Padding (top, bottom, left, right). Please adjust to include chin at least')

parser.add_argument('--face_det_batch_size', type=int, 
					help='Batch size for face detection', default=16)
parser.add_argument('--wav2lip_batch_size', type=int, help='Batch size for Wav2Lip model(s)', default=128)

parser.add_argument('--resize_factor', default=1, type=int, 
			help='Reduce the resolution by this factor. Sometimes, best results are obtained at 480p or 720p')

args = parser.parse_args()
img_size = 96
static = False
fps = 25
pads = [0, 10, 0, 0]
face_det_batch_size = 16
wav2lip_batch_size = 128
resize_factor



if os.path.isfile(video_path) and video_path.split('.')[1] in ['jpg', 'png', 'jpeg']:
	args.static = True

def get_smoothened_boxes(boxes, T):
	for i in range(len(boxes)):
		if i + T > len(boxes):
			window = boxes[len(boxes) - T:]
		else:
			window = boxes[i : i + T]
		boxes[i] = np.mean(window, axis=0)
	return boxes

def face_detect(images):
	detector = face_detection.FaceAlignment(face_detection.LandmarksType._2D, 
											flip_input=False, device=device)

	batch_size = args.face_det_batch_size
	
	while 1:
		predictions = []
		try:
			for i in tqdm(range(0, len(images), batch_size)):
				predictions.extend(detector.get_detections_for_batch(np.array(images[i:i + batch_size])))
		except RuntimeError:
			if batch_size == 1: 
				raise RuntimeError('Image too big to run face detection on GPU. Please use the --resize_factor argument')
			batch_size //= 2
			print('Recovering from OOM error; New batch size: {}'.format(batch_size))
			continue
		break

	results = []
	pady1, pady2, padx1, padx2 = args.pads
	for rect, image in zip(predictions, images):
		if rect is None:
			raise ValueError('Face not detected! Ensure the video contains a face in all the frames.')

		y1 = max(0, rect[1] - pady1)
		y2 = min(image.shape[0], rect[3] + pady2)
		x1 = max(0, rect[0] - padx1)
		x2 = min(image.shape[1], rect[2] + padx2)
		
		results.append([x1, y1, x2, y2])

	boxes = get_smoothened_boxes(np.array(results), T=5)
	results = [[image[y1: y2, x1:x2], (y1, y2, x1, x2)] for image, (x1, y1, x2, y2) in zip(images, boxes)]

	del detector
	return results 

def datagen(frames, mels):
	img_batch, mel_batch, frame_batch, coords_batch = [], [], [], []

	if not args.static:
		face_det_results = face_detect(frames) # BGR2RGB for CNN face detection
	else:
		face_det_results = face_detect([frames[0]])

	for i, m in enumerate(mels):
		idx = 0 if args.static else i%len(frames)
		frame_to_save = frames[idx].copy()
		face, coords = face_det_results[idx].copy()

		face = cv2.resize(face, (img_size, img_size))
			
		img_batch.append(face)
		mel_batch.append(m)
		frame_batch.append(frame_to_save)
		coords_batch.append(coords)

		if len(img_batch) >= args.wav2lip_batch_size:
			img_batch, mel_batch = np.asarray(img_batch), np.asarray(mel_batch)

			img_masked = img_batch.copy()
			img_masked[:, img_size//2:] = 0

			img_batch = np.concatenate((img_masked, img_batch), axis=3) / 255.
			mel_batch = np.reshape(mel_batch, [len(mel_batch), mel_batch.shape[1], mel_batch.shape[2], 1])

			yield img_batch, mel_batch, frame_batch, coords_batch
			img_batch, mel_batch, frame_batch, coords_batch = [], [], [], []

	if len(img_batch) > 0:
		img_batch, mel_batch = np.asarray(img_batch), np.asarray(mel_batch)

		img_masked = img_batch.copy()
		img_masked[:, img_size//2:] = 0

		img_batch = np.concatenate((img_masked, img_batch), axis=3) / 255.
		mel_batch = np.reshape(mel_batch, [len(mel_batch), mel_batch.shape[1], mel_batch.shape[2], 1])

		yield img_batch, mel_batch, frame_batch, coords_batch

mel_step_size = 16
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} for inference.'.format(device))

def _load(checkpoint_path):
	if device == 'cuda':
		checkpoint = torch.load(checkpoint_path)
	else:
		checkpoint = torch.load(checkpoint_path,
								map_location=lambda storage, loc: storage)
	return checkpoint

def load_model(path):
	model = Wav2Lip()
	print("Load checkpoint from: {}".format(path))
	checkpoint = _load(path)
	s = checkpoint["state_dict"]
	new_s = {}
	for k, v in s.items():
		new_s[k.replace('module.', '')] = v
	model.load_state_dict(new_s)

	model = model.to(device)
	return model.eval()

def main():
	if not os.path.isfile(video_path):
		fnames = list(glob(os.path.join(video_path, '*.jpg')))
		sorted_fnames = sorted(fnames, key=lambda f: int(os.path.basename(f).split('.')[0]))
		full_frames = [cv2.imread(f) for f in sorted_fnames]

	elif video_path.split('.')[1] in ['jpg', 'png', 'jpeg']:
		full_frames = [cv2.imread(video_path)]
		fps = args.fps

	else:
		video_stream = cv2.VideoCapture(video_path)
		fps = video_stream.get(cv2.CAP_PROP_FPS)

		print('Reading video frames...')

		full_frames = []
		while 1:
			still_reading, frame = video_stream.read()
			if not still_reading:
				video_stream.release()
				break
			if args.resize_factor > 1:
				frame = cv2.resize(frame, (frame.shape[1]//args.resize_factor, frame.shape[0]//args.resize_factor))

			full_frames.append(frame)

	print ("Number of frames available for inference: "+str(len(full_frames)))

	if not audio_path.endswith('.wav'):
		print('Extracting raw audio...')
		command = 'ffmpeg -y -i {} -strict -2 {}'.format(audio_path, 'temp/temp.wav')

		subprocess.call(command, shell=True)
		audio_path = 'temp/temp.wav'

	wav = audio.load_wav(audio_path, 16000)
	mel = audio.melspectrogram(wav)
	print(mel.shape)

	if np.isnan(mel.reshape(-1)).sum() > 0:
		raise ValueError('Mel contains nan! Using a TTS voice? Add a small epsilon noise to the wav file and try again')

	mel_chunks = []
	mel_idx_multiplier = 80./fps 
	i = 0
	while 1:
		start_idx = int(i * mel_idx_multiplier)
		if start_idx + mel_step_size > len(mel[0]):
			break
		mel_chunks.append(mel[:, start_idx : start_idx + mel_step_size])
		i += 1

	print("Length of mel chunks: {}".format(len(mel_chunks)))

	full_frames = full_frames[:len(mel_chunks)]

	batch_size = args.wav2lip_batch_size
	gen = datagen(full_frames.copy(), mel_chunks)

	for i, (img_batch, mel_batch, frames, coords) in enumerate(tqdm(gen, 
											total=int(np.ceil(float(len(mel_chunks))/batch_size)))):
		if i == 0:
			model = load_model(checkpoint_path)
			print ("Model loaded")

			frame_h, frame_w = full_frames[0].shape[:-1]
			out = cv2.VideoWriter('temp/result.avi', 
									cv2.VideoWriter_fourcc(*'DIVX'), fps, (frame_w, frame_h))

		img_batch = torch.FloatTensor(np.transpose(img_batch, (0, 3, 1, 2))).to(device)
		mel_batch = torch.FloatTensor(np.transpose(mel_batch, (0, 3, 1, 2))).to(device)

		with torch.no_grad():
			pred = model(mel_batch, img_batch)

		pred = pred.cpu().numpy().transpose(0, 2, 3, 1) * 255.
		
		for p, f, c in zip(pred, frames, coords):
			y1, y2, x1, x2 = c
			p = cv2.resize(p.astype(np.uint8), (x2 - x1, y2 - y1))

			f[y1:y2, x1:x2] = p
			out.write(f)

	out.release()

	command = 'ffmpeg -y -i {} -i {} -strict -2 -q:v 1 {}'.format(audio_path, 'temp/result.avi', args.outfile)
	subprocess.call(command, shell=True)

if __name__ == '__main__':
	main()
# Out:
# mv: cannot stat 'home/Deepfake/weights': No such file or directory
